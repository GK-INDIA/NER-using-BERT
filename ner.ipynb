# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C://Users//igyan//OneDrive//Documents//Github//NER-using-BERT//dataset")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\igyan\OneDrive\Documents\Github\NER-using-BERT\ner.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/igyan/OneDrive/Documents/Github/NER-using-BERT/ner.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv(r"C://Users//igyan//OneDrive//Documents//Github//NER-using-BERT//dataset")
#
# ...
